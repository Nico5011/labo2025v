# %% [markdown]
# <a href="https://colab.research.google.com/github/Nico5011/labo2025v/blob/main/src/ensembles/594_TareaHogar_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea para el Hogar 05

# %% [markdown]
# Esta Tarea para el Hogar 05 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Nov 02 11:08:43 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660468 35.3 1454462    77.7 1438470  76.9
# Vcells 1226772  9.4 8388608    64.0 1975128  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 5940
PARAM$semilla_primigenia <- 523519

# %%
PARAM$kaggle$competencia <- "labo-i-2025-virtual-analista-sr"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_iterations", lower= 8L, upper= 2048L),     # Mayor a 0, a mayor numero mayor precisión con small learning_rate
  makeNumericParam("learning_rate", lower= 0.01, upper= 0.3),  #Default 0.1, restricción mayor a 0. Tiene que ser pequeño.
  makeNumericParam("feature_fraction", lower= 0.1, upper= 1.0), # 0.0 < feature_fraction <= 1.0
  makeIntegerParam("num_leaves", lower= 8L, upper= 2048L), # Use large num_leaves (may cause over-fitting) 1 < num_leaves <= 131072. Default 31.
  makeIntegerParam("min_data_in_leaf", lower= 1L, upper= 8000L) # min_data_in_leaf >= 0. # default 20.
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 100 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83701
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Sun Nov 02 11:28:38 PM 2025 AUC 0.923531758545659
#
# Sun Nov 02 11:30:51 PM 2025 AUC 0.927078541786751
#
# Sun Nov 02 11:32:43 PM 2025 AUC 0.926119278111707
#
# Sun Nov 02 11:35:07 PM 2025 AUC 0.928121956377571
#
# Sun Nov 02 11:35:28 PM 2025 AUC 0.923844304346458
#
# Sun Nov 02 11:39:50 PM 2025 AUC 0.9246276248562
#
# Sun Nov 02 11:41:36 PM 2025 AUC 0.926277722599782
#
# Sun Nov 02 11:41:52 PM 2025 AUC 0.924726358083511
#
# Sun Nov 02 11:45:14 PM 2025 AUC 0.928447832795633
#
# Sun Nov 02 11:49:09 PM 2025 AUC 0.927915635924312
#
# Sun Nov 02 11:50:55 PM 2025 AUC 0.923981013723387
#
# Sun Nov 02 11:52:22 PM 2025 AUC 0.925693747459342
#
# Sun Nov 02 11:54:10 PM 2025 AUC 0.924779536259992
#
# Sun Nov 02 11:58:26 PM 2025 AUC 0.925001056567245
#
# Sun Nov 02 11:59:05 PM 2025 AUC 0.923637873816791
#
# Mon Nov 03 12:03:25 AM 2025 AUC 0.918397632786754
#
# Mon Nov 03 12:07:27 AM 2025 AUC 0.924728737204919
#
# Mon Nov 03 12:08:15 AM 2025 AUC 0.927803453175155
#
# Mon Nov 03 12:08:31 AM 2025 AUC 0.915502046290656
#
# Mon Nov 03 12:10:45 AM 2025 AUC 0.924775159485197
#
# [mbo] 0: num_iterations=920; learning_rate=0.229; feature_fraction=0.288; num_leaves=1215; min_data_in_leaf=1304 : y = 0.924 : 147.7 secs : initdesign
#
# [mbo] 0: num_iterations=1103; learning_rate=0.201; feature_fraction=0.621; num_leaves=314; min_data_in_leaf=3383 : y = 0.927 : 133.1 secs : initdesign
#
# [mbo] 0: num_iterations=671; learning_rate=0.275; feature_fraction=0.552; num_leaves=1336; min_data_in_leaf=4193 : y = 0.926 : 112.0 secs : initdesign
#
# [mbo] 0: num_iterations=787; learning_rate=0.138; feature_fraction=0.534; num_leaves=1076; min_data_in_leaf=2547 : y = 0.928 : 143.2 secs : initdesign
#
# [mbo] 0: num_iterations=227; learning_rate=0.188; feature_fraction=0.747; num_leaves=744; min_data_in_leaf=6047 : y = 0.924 : 21.9 secs : initdesign
#
# [mbo] 0: num_iterations=1721; learning_rate=0.179; feature_fraction=0.402; num_leaves=1657; min_data_in_leaf=6525 : y = 0.925 : 261.8 secs : initdesign
#
# [mbo] 0: num_iterations=1194; learning_rate=0.142; feature_fraction=0.97; num_leaves=366; min_data_in_leaf=5792 : y = 0.926 : 106.0 secs : initdesign
#
# [mbo] 0: num_iterations=125; learning_rate=0.12; feature_fraction=0.2; num_leaves=1004; min_data_in_leaf=4848 : y = 0.925 : 15.8 secs : initdesign
#
# [mbo] 0: num_iterations=1615; learning_rate=0.0449; feature_fraction=0.795; num_leaves=1750; min_data_in_leaf=1835 : y = 0.928 : 202.0 secs : initdesign
#
# [mbo] 0: num_iterations=1340; learning_rate=0.0942; feature_fraction=0.267; num_leaves=906; min_data_in_leaf=558 : y = 0.928 : 235.4 secs : initdesign
#
# [mbo] 0: num_iterations=1303; learning_rate=0.243; feature_fraction=0.896; num_leaves=700; min_data_in_leaf=7906 : y = 0.924 : 105.5 secs : initdesign
#
# [mbo] 0: num_iterations=930; learning_rate=0.0546; feature_fraction=0.656; num_leaves=92; min_data_in_leaf=5406 : y = 0.926 : 87.3 secs : initdesign
#
# [mbo] 0: num_iterations=593; learning_rate=0.266; feature_fraction=0.502; num_leaves=593; min_data_in_leaf=3165 : y = 0.925 : 107.7 secs : initdesign
#
# [mbo] 0: num_iterations=1859; learning_rate=0.0385; feature_fraction=0.334; num_leaves=1308; min_data_in_leaf=7504 : y = 0.925 : 256.0 secs : initdesign
#
# [mbo] 0: num_iterations=366; learning_rate=0.0734; feature_fraction=0.134; num_leaves=2047; min_data_in_leaf=7196 : y = 0.924 : 38.7 secs : initdesign
#
# [mbo] 0: num_iterations=1971; learning_rate=0.215; feature_fraction=0.154; num_leaves=1941; min_data_in_leaf=361 : y = 0.918 : 259.9 secs : initdesign
#
# [mbo] 0: num_iterations=1782; learning_rate=0.162; feature_fraction=0.823; num_leaves=131; min_data_in_leaf=1167 : y = 0.925 : 242.7 secs : initdesign
#
# [mbo] 0: num_iterations=469; learning_rate=0.111; feature_fraction=0.925; num_leaves=1456; min_data_in_leaf=3855 : y = 0.928 : 47.7 secs : initdesign
#
# [mbo] 0: num_iterations=88; learning_rate=0.011; feature_fraction=0.455; num_leaves=425; min_data_in_leaf=2091 : y = 0.916 : 15.8 secs : initdesign
#
# [mbo] 0: num_iterations=1454; learning_rate=0.286; feature_fraction=0.693; num_leaves=1623; min_data_in_leaf=4654 : y = 0.925 : 134.2 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Mon Nov 03 12:12:47 AM 2025 AUC 0.926354316118095
#
# [mbo] 1: num_iterations=1231; learning_rate=0.0956; feature_fraction=0.719; num_leaves=1456; min_data_in_leaf=3522 : y = 0.926 : 122.0 secs : infill_ei
#
# Mon Nov 03 12:17:15 AM 2025 AUC 0.926574159111828
#
# [mbo] 2: num_iterations=1540; learning_rate=0.059; feature_fraction=0.675; num_leaves=489; min_data_in_leaf=16 : y = 0.927 : 267.5 secs : infill_ei
#
# Mon Nov 03 12:20:03 AM 2025 AUC 0.923108406003478
#
# [mbo] 3: num_iterations=851; learning_rate=0.113; feature_fraction=0.319; num_leaves=575; min_data_in_leaf=33 : y = 0.923 : 166.8 secs : infill_ei
#
# Mon Nov 03 12:23:01 AM 2025 AUC 0.928469870226999
#
# [mbo] 4: num_iterations=1507; learning_rate=0.0506; feature_fraction=0.701; num_leaves=1061; min_data_in_leaf=1949 : y = 0.928 : 178.2 secs : infill_ei
#
# Saved the current state after iteration 5 in the file bayesiana.RDATA.
#
# Mon Nov 03 12:28:10 AM 2025 AUC 0.929418736862076
#
# [mbo] 5: num_iterations=1558; learning_rate=0.0712; feature_fraction=0.522; num_leaves=1233; min_data_in_leaf=1264 : y = 0.929 : 308.0 secs : infill_ei
#
# Mon Nov 03 12:29:12 AM 2025 AUC 0.925697232596925
#
# [mbo] 6: num_iterations=687; learning_rate=0.141; feature_fraction=0.756; num_leaves=1187; min_data_in_leaf=5503 : y = 0.926 : 61.8 secs : infill_ei
#
# Mon Nov 03 12:32:21 AM 2025 AUC 0.924871250927038
#
# [mbo] 7: num_iterations=1663; learning_rate=0.0737; feature_fraction=0.13; num_leaves=1066; min_data_in_leaf=1636 : y = 0.925 : 189.1 secs : infill_ei
#
# Mon Nov 03 12:36:54 AM 2025 AUC 0.927805696960432
#
# [mbo] 8: num_iterations=1390; learning_rate=0.0826; feature_fraction=0.551; num_leaves=1636; min_data_in_leaf=1219 : y = 0.928 : 272.1 secs : infill_ei
#
# Saved the current state after iteration 9 in the file bayesiana.RDATA.
#
# Mon Nov 03 12:41:27 AM 2025 AUC 0.929185973967888
#
# [mbo] 9: num_iterations=1534; learning_rate=0.0298; feature_fraction=0.453; num_leaves=744; min_data_in_leaf=2075 : y = 0.929 : 272.3 secs : infill_ei
#
# Mon Nov 03 12:46:05 AM 2025 AUC 0.927969663424319
#
# [mbo] 10: num_iterations=1578; learning_rate=0.0781; feature_fraction=0.522; num_leaves=903; min_data_in_leaf=3028 : y = 0.928 : 278.0 secs : infill_ei
#
# Mon Nov 03 12:51:17 AM 2025 AUC 0.930521122590093
#
# [mbo] 11: num_iterations=1522; learning_rate=0.0101; feature_fraction=0.446; num_leaves=1222; min_data_in_leaf=754 : y = 0.931 : 312.1 secs : infill_ei
#
# Saved the current state after iteration 12 in the file bayesiana.RDATA.
#
# Mon Nov 03 12:57:01 AM 2025 AUC 0.929866524342877
#
# [mbo] 12: num_iterations=1534; learning_rate=0.0108; feature_fraction=0.372; num_leaves=1617; min_data_in_leaf=323 : y = 0.93 : 343.0 secs : infill_ei
#
# Mon Nov 03 01:01:14 AM 2025 AUC 0.92928727161473
#
# [mbo] 13: num_iterations=1493; learning_rate=0.0106; feature_fraction=0.39; num_leaves=1241; min_data_in_leaf=1854 : y = 0.929 : 252.6 secs : infill_ei
#
# Mon Nov 03 01:03:05 AM 2025 AUC 0.927244735840114
#
# [mbo] 14: num_iterations=849; learning_rate=0.102; feature_fraction=0.951; num_leaves=1096; min_data_in_leaf=1610 : y = 0.927 : 110.7 secs : infill_ei
#
# Saved the current state after iteration 15 in the file bayesiana.RDATA.
#
# Mon Nov 03 01:15:09 AM 2025 AUC 0.928746072686567
#
# [mbo] 15: num_iterations=1587; learning_rate=0.0102; feature_fraction=0.508; num_leaves=1402; min_data_in_leaf=2 : y = 0.929 : 723.5 secs : infill_ei
#
# Saved the current state after iteration 16 in the file bayesiana.RDATA.
#
# Mon Nov 03 01:21:16 AM 2025 AUC 0.931359875726189
#
# [mbo] 16: num_iterations=1890; learning_rate=0.0119; feature_fraction=0.4; num_leaves=1027; min_data_in_leaf=757 : y = 0.931 : 366.9 secs : infill_ei
#
# Mon Nov 03 01:27:11 AM 2025 AUC 0.929479383180762
#
# [mbo] 17: num_iterations=1812; learning_rate=0.0103; feature_fraction=0.469; num_leaves=1079; min_data_in_leaf=1140 : y = 0.929 : 354.1 secs : infill_ei
#
# Saved the current state after iteration 18 in the file bayesiana.RDATA.
#
# Mon Nov 03 01:32:44 AM 2025 AUC 0.92915125795276
#
# [mbo] 18: num_iterations=1679; learning_rate=0.0453; feature_fraction=0.399; num_leaves=692; min_data_in_leaf=639 : y = 0.929 : 332.5 secs : infill_ei
#
# Mon Nov 03 01:40:58 AM 2025 AUC 0.930840450123794
#
# [mbo] 19: num_iterations=2004; learning_rate=0.01; feature_fraction=0.402; num_leaves=1141; min_data_in_leaf=255 : y = 0.931 : 494.1 secs : infill_ei
#
# Saved the current state after iteration 20 in the file bayesiana.RDATA.
#
# Mon Nov 03 01:46:49 AM 2025 AUC 0.928763444528506
#
# [mbo] 20: num_iterations=1933; learning_rate=0.0112; feature_fraction=0.387; num_leaves=1614; min_data_in_leaf=1139 : y = 0.929 : 350.7 secs : infill_ei
#
# Mon Nov 03 01:49:08 AM 2025 AUC 0.927297172593612
#
# [mbo] 21: num_iterations=1441; learning_rate=0.0342; feature_fraction=0.922; num_leaves=1084; min_data_in_leaf=4164 : y = 0.927 : 138.1 secs : infill_ei
#
# Mon Nov 03 01:54:21 AM 2025 AUC 0.921616677524563
#
# [mbo] 22: num_iterations=1532; learning_rate=0.115; feature_fraction=0.443; num_leaves=1036; min_data_in_leaf=20 : y = 0.922 : 312.9 secs : infill_ei
#
# Saved the current state after iteration 23 in the file bayesiana.RDATA.
#
# Mon Nov 03 02:02:57 AM 2025 AUC 0.928227382932567
#
# [mbo] 23: num_iterations=1682; learning_rate=0.0189; feature_fraction=0.406; num_leaves=1030; min_data_in_leaf=11 : y = 0.928 : 515.9 secs : infill_ei
#
# Mon Nov 03 02:10:16 AM 2025 AUC 0.930303718794366
#
# [mbo] 24: num_iterations=1916; learning_rate=0.0101; feature_fraction=0.515; num_leaves=1223; min_data_in_leaf=556 : y = 0.93 : 438.3 secs : infill_ei
#
# Saved the current state after iteration 25 in the file bayesiana.RDATA.
#
# Mon Nov 03 02:15:47 AM 2025 AUC 0.930176463956485
#
# [mbo] 25: num_iterations=1933; learning_rate=0.0122; feature_fraction=0.281; num_leaves=1170; min_data_in_leaf=671 : y = 0.93 : 330.3 secs : infill_ei
#
# Mon Nov 03 02:21:56 AM 2025 AUC 0.929363195343614
#
# [mbo] 26: num_iterations=2048; learning_rate=0.0648; feature_fraction=0.45; num_leaves=1163; min_data_in_leaf=2045 : y = 0.929 : 368.7 secs : infill_ei
#
# Saved the current state after iteration 27 in the file bayesiana.RDATA.
#
# Mon Nov 03 02:28:27 AM 2025 AUC 0.931554965395837
#
# [mbo] 27: num_iterations=2042; learning_rate=0.0108; feature_fraction=0.38; num_leaves=644; min_data_in_leaf=777 : y = 0.932 : 390.6 secs : infill_ei
#
# Mon Nov 03 02:35:09 AM 2025 AUC 0.932088249068544
#
# [mbo] 28: num_iterations=1975; learning_rate=0.0101; feature_fraction=0.4; num_leaves=512; min_data_in_leaf=611 : y = 0.932 : 401.5 secs : infill_ei
#
# Saved the current state after iteration 29 in the file bayesiana.RDATA.
#
# Mon Nov 03 02:39:07 AM 2025 AUC 0.930206009844638
#
# [mbo] 29: num_iterations=1304; learning_rate=0.034; feature_fraction=0.331; num_leaves=1174; min_data_in_leaf=730 : y = 0.93 : 237.3 secs : infill_ei
#
# Mon Nov 03 02:43:26 AM 2025 AUC 0.928246625795593
#
# [mbo] 30: num_iterations=2018; learning_rate=0.0617; feature_fraction=0.723; num_leaves=229; min_data_in_leaf=1564 : y = 0.928 : 258.9 secs : infill_ei
#
# Mon Nov 03 02:50:01 AM 2025 AUC 0.930004404397648
#
# [mbo] 31: num_iterations=1947; learning_rate=0.0325; feature_fraction=0.415; num_leaves=617; min_data_in_leaf=667 : y = 0.93 : 394.0 secs : infill_ei
#
# Saved the current state after iteration 32 in the file bayesiana.RDATA.
#
# Mon Nov 03 02:56:27 AM 2025 AUC 0.926696799407895
#
# [mbo] 32: num_iterations=1427; learning_rate=0.0465; feature_fraction=0.438; num_leaves=1949; min_data_in_leaf=110 : y = 0.927 : 385.1 secs : infill_ei
#
# Mon Nov 03 03:00:47 AM 2025 AUC 0.930739440042161
#
# [mbo] 33: num_iterations=1409; learning_rate=0.0101; feature_fraction=0.338; num_leaves=575; min_data_in_leaf=665 : y = 0.931 : 259.7 secs : infill_ei
#
# Saved the current state after iteration 34 in the file bayesiana.RDATA.
#
# Mon Nov 03 03:04:19 AM 2025 AUC 0.928671405454722
#
# [mbo] 34: num_iterations=1315; learning_rate=0.0634; feature_fraction=0.368; num_leaves=27; min_data_in_leaf=1445 : y = 0.929 : 211.9 secs : infill_ei
#
# Mon Nov 03 03:06:10 AM 2025 AUC 0.926139049705567
#
# [mbo] 35: num_iterations=1027; learning_rate=0.17; feature_fraction=0.999; num_leaves=1983; min_data_in_leaf=3068 : y = 0.926 : 110.1 secs : infill_ei
#
# Mon Nov 03 03:09:25 AM 2025 AUC 0.930558789836134
#
# [mbo] 36: num_iterations=1210; learning_rate=0.01; feature_fraction=0.254; num_leaves=991; min_data_in_leaf=727 : y = 0.931 : 195.2 secs : infill_ei
#
# Mon Nov 03 03:19:54 AM 2025 AUC 0.927907219036022
#
# [mbo] 37: num_iterations=1943; learning_rate=0.01; feature_fraction=0.995; num_leaves=1607; min_data_in_leaf=159 : y = 0.928 : 627.7 secs : infill_ei
#
# Saved the current state after iteration 38 in the file bayesiana.RDATA.
#
# Mon Nov 03 03:21:31 AM 2025 AUC 0.92557173117938
#
# [mbo] 38: num_iterations=1182; learning_rate=0.0592; feature_fraction=1; num_leaves=2019; min_data_in_leaf=7099 : y = 0.926 : 97.3 secs : infill_ei
#
# Mon Nov 03 03:27:00 AM 2025 AUC 0.928916593097137
#
# [mbo] 39: num_iterations=1948; learning_rate=0.0102; feature_fraction=0.817; num_leaves=123; min_data_in_leaf=619 : y = 0.929 : 327.6 secs : infill_ei
#
# Mon Nov 03 03:31:11 AM 2025 AUC 0.927928195231799
#
# [mbo] 40: num_iterations=2034; learning_rate=0.0687; feature_fraction=0.998; num_leaves=1724; min_data_in_leaf=1903 : y = 0.928 : 251.4 secs : infill_ei
#
# Saved the current state after iteration 41 in the file bayesiana.RDATA.
#
# Mon Nov 03 03:36:44 AM 2025 AUC 0.928243473788973
#
# [mbo] 41: num_iterations=2036; learning_rate=0.0103; feature_fraction=0.401; num_leaves=295; min_data_in_leaf=2734 : y = 0.928 : 332.3 secs : infill_ei
#
# Mon Nov 03 03:42:01 AM 2025 AUC 0.930940390074558
#
# [mbo] 42: num_iterations=1310; learning_rate=0.01; feature_fraction=0.436; num_leaves=981; min_data_in_leaf=326 : y = 0.931 : 315.9 secs : infill_ei
#
# Saved the current state after iteration 43 in the file bayesiana.RDATA.
#
# Mon Nov 03 03:46:11 AM 2025 AUC 0.929533279063121
#
# [mbo] 43: num_iterations=1111; learning_rate=0.0101; feature_fraction=0.87; num_leaves=1119; min_data_in_leaf=319 : y = 0.93 : 249.8 secs : infill_ei
#
# Mon Nov 03 03:50:08 AM 2025 AUC 0.928579452442464
#
# [mbo] 44: num_iterations=1479; learning_rate=0.0607; feature_fraction=1; num_leaves=1142; min_data_in_leaf=880 : y = 0.929 : 235.8 secs : infill_ei
#
# Mon Nov 03 03:53:35 AM 2025 AUC 0.929815639510128
#
# [mbo] 45: num_iterations=1083; learning_rate=0.01; feature_fraction=0.918; num_leaves=2048; min_data_in_leaf=521 : y = 0.93 : 206.7 secs : infill_ei
#
# Saved the current state after iteration 46 in the file bayesiana.RDATA.
#
# Mon Nov 03 03:57:01 AM 2025 AUC 0.929458857891296
#
# [mbo] 46: num_iterations=1328; learning_rate=0.01; feature_fraction=1; num_leaves=1763; min_data_in_leaf=906 : y = 0.929 : 205.2 secs : infill_ei
#
# Mon Nov 03 04:03:11 AM 2025 AUC 0.930691758376413
#
# [mbo] 47: num_iterations=1898; learning_rate=0.0101; feature_fraction=0.376; num_leaves=148; min_data_in_leaf=586 : y = 0.931 : 369.3 secs : infill_ei
#
# Mon Nov 03 04:04:23 AM 2025 AUC 0.921455801523251
#
# [mbo] 48: num_iterations=786; learning_rate=0.3; feature_fraction=0.1; num_leaves=1960; min_data_in_leaf=7996 : y = 0.921 : 71.6 secs : infill_ei
#
# Saved the current state after iteration 49 in the file bayesiana.RDATA.
#
# Mon Nov 03 04:08:33 AM 2025 AUC 0.931115259882171
#
# [mbo] 49: num_iterations=1188; learning_rate=0.0103; feature_fraction=0.475; num_leaves=1624; min_data_in_leaf=799 : y = 0.931 : 249.4 secs : infill_ei
#
# Mon Nov 03 04:09:29 AM 2025 AUC 0.927719637680849
#
# [mbo] 50: num_iterations=469; learning_rate=0.147; feature_fraction=0.994; num_leaves=138; min_data_in_leaf=1976 : y = 0.928 : 55.7 secs : infill_ei
#
# Mon Nov 03 04:10:47 AM 2025 AUC 0.926983805521327
#
# [mbo] 51: num_iterations=825; learning_rate=0.135; feature_fraction=0.916; num_leaves=13; min_data_in_leaf=3370 : y = 0.927 : 77.5 secs : infill_ei
#
# Mon Nov 03 04:16:26 AM 2025 AUC 0.927547092022013
#
# [mbo] 52: num_iterations=1903; learning_rate=0.135; feature_fraction=0.473; num_leaves=247; min_data_in_leaf=2504 : y = 0.928 : 338.2 secs : infill_ei
#
# Saved the current state after iteration 53 in the file bayesiana.RDATA.
#
# Mon Nov 03 04:19:33 AM 2025 AUC 0.926386283924047
#
# [mbo] 53: num_iterations=2048; learning_rate=0.108; feature_fraction=0.868; num_leaves=641; min_data_in_leaf=4939 : y = 0.926 : 186.5 secs : infill_ei
#
# Mon Nov 03 04:23:06 AM 2025 AUC 0.927532454200421
#
# [mbo] 54: num_iterations=1908; learning_rate=0.01; feature_fraction=0.964; num_leaves=984; min_data_in_leaf=2499 : y = 0.928 : 213.1 secs : infill_ei
#
# Mon Nov 03 04:25:19 AM 2025 AUC 0.929083732224941
#
# [mbo] 55: num_iterations=1075; learning_rate=0.0368; feature_fraction=0.998; num_leaves=1677; min_data_in_leaf=1861 : y = 0.929 : 132.4 secs : infill_ei
#
# Mon Nov 03 04:28:34 AM 2025 AUC 0.928418641274814
#
# [mbo] 56: num_iterations=1112; learning_rate=0.0647; feature_fraction=0.409; num_leaves=1189; min_data_in_leaf=1780 : y = 0.928 : 194.1 secs : infill_ei
#
# Saved the current state after iteration 57 in the file bayesiana.RDATA.
#
# Mon Nov 03 04:28:36 AM 2025 AUC 0.911246468826366
#
# [mbo] 57: num_iterations=8; learning_rate=0.152; feature_fraction=0.995; num_leaves=1421; min_data_in_leaf=2372 : y = 0.911 : 1.8 secs : infill_ei
#
# Mon Nov 03 04:32:32 AM 2025 AUC 0.930754276733248
#
# [mbo] 58: num_iterations=1225; learning_rate=0.01; feature_fraction=0.59; num_leaves=438; min_data_in_leaf=742 : y = 0.931 : 235.8 secs : infill_ei
#
# Mon Nov 03 04:35:28 AM 2025 AUC 0.929340392176547
#
# [mbo] 59: num_iterations=926; learning_rate=0.0101; feature_fraction=0.557; num_leaves=1745; min_data_in_leaf=1427 : y = 0.929 : 175.0 secs : infill_ei
#
# Mon Nov 03 04:39:06 AM 2025 AUC 0.931080617655325
#
# [mbo] 60: num_iterations=1051; learning_rate=0.0108; feature_fraction=0.417; num_leaves=808; min_data_in_leaf=582 : y = 0.931 : 217.1 secs : infill_ei
#
# Saved the current state after iteration 61 in the file bayesiana.RDATA.
#
# Mon Nov 03 04:39:58 AM 2025 AUC 0.925766073101709
#
# [mbo] 61: num_iterations=495; learning_rate=0.143; feature_fraction=0.124; num_leaves=200; min_data_in_leaf=4111 : y = 0.926 : 51.9 secs : infill_ei
#
# Mon Nov 03 04:41:09 AM 2025 AUC 0.927533393114348
#
# [mbo] 62: num_iterations=723; learning_rate=0.0233; feature_fraction=0.999; num_leaves=2048; min_data_in_leaf=4142 : y = 0.928 : 70.4 secs : infill_ei
#
# Mon Nov 03 04:44:12 AM 2025 AUC 0.92787512489435
#
# [mbo] 63: num_iterations=1057; learning_rate=0.0102; feature_fraction=0.45; num_leaves=663; min_data_in_leaf=2837 : y = 0.928 : 182.2 secs : infill_ei
#
# Mon Nov 03 04:45:37 AM 2025 AUC 0.928705457034988
#
# [mbo] 64: num_iterations=608; learning_rate=0.0531; feature_fraction=0.999; num_leaves=425; min_data_in_leaf=1286 : y = 0.929 : 84.6 secs : infill_ei
#
# Mon Nov 03 04:46:11 AM 2025 AUC 0.924935859744755
#
# [mbo] 65: num_iterations=430; learning_rate=0.0895; feature_fraction=1; num_leaves=206; min_data_in_leaf=7997 : y = 0.925 : 33.6 secs : infill_ei
#
# Mon Nov 03 04:50:17 AM 2025 AUC 0.930262906722278
#
# [mbo] 66: num_iterations=1159; learning_rate=0.0587; feature_fraction=0.53; num_leaves=724; min_data_in_leaf=862 : y = 0.93 : 245.4 secs : infill_ei
#
# Saved the current state after iteration 67 in the file bayesiana.RDATA.
#
# Mon Nov 03 04:51:24 AM 2025 AUC 0.926918266261889
#
# [mbo] 67: num_iterations=630; learning_rate=0.075; feature_fraction=1; num_leaves=719; min_data_in_leaf=3069 : y = 0.927 : 66.8 secs : infill_ei
#
# Mon Nov 03 04:53:28 AM 2025 AUC 0.930227668558446
#
# [mbo] 68: num_iterations=693; learning_rate=0.0103; feature_fraction=0.999; num_leaves=1793; min_data_in_leaf=615 : y = 0.93 : 123.2 secs : infill_ei
#
# Mon Nov 03 04:58:24 AM 2025 AUC 0.925797262954426
#
# [mbo] 69: num_iterations=1917; learning_rate=0.0101; feature_fraction=0.388; num_leaves=2009; min_data_in_leaf=4715 : y = 0.926 : 296.0 secs : infill_ei
#
# Mon Nov 03 05:02:50 AM 2025 AUC 0.928322708755842
#
# [mbo] 70: num_iterations=1604; learning_rate=0.0101; feature_fraction=0.397; num_leaves=2043; min_data_in_leaf=2596 : y = 0.928 : 265.3 secs : infill_ei
#
# Saved the current state after iteration 71 in the file bayesiana.RDATA.
#
# Mon Nov 03 05:07:55 AM 2025 AUC 0.924905865469115
#
# [mbo] 71: num_iterations=2047; learning_rate=0.2; feature_fraction=0.416; num_leaves=9; min_data_in_leaf=7750 : y = 0.925 : 304.3 secs : infill_ei
#
# Mon Nov 03 05:10:15 AM 2025 AUC 0.927374534042208
#
# [mbo] 72: num_iterations=878; learning_rate=0.181; feature_fraction=0.398; num_leaves=2047; min_data_in_leaf=4166 : y = 0.927 : 139.1 secs : infill_ei
#
# Mon Nov 03 05:12:39 AM 2025 AUC 0.92922825972213
#
# [mbo] 73: num_iterations=937; learning_rate=0.0106; feature_fraction=0.974; num_leaves=613; min_data_in_leaf=921 : y = 0.929 : 144.2 secs : infill_ei
#
# Mon Nov 03 05:14:36 AM 2025 AUC 0.927598115818269
#
# [mbo] 74: num_iterations=514; learning_rate=0.0661; feature_fraction=0.995; num_leaves=2044; min_data_in_leaf=364 : y = 0.928 : 116.1 secs : infill_ei
#
# Saved the current state after iteration 75 in the file bayesiana.RDATA.
#
# Mon Nov 03 05:19:44 AM 2025 AUC 0.925359937707146
#
# [mbo] 75: num_iterations=724; learning_rate=0.0102; feature_fraction=0.698; num_leaves=837; min_data_in_leaf=20 : y = 0.925 : 307.3 secs : infill_ei
#
# Mon Nov 03 05:23:22 AM 2025 AUC 0.930368954829635
#
# [mbo] 76: num_iterations=1142; learning_rate=0.035; feature_fraction=0.38; num_leaves=354; min_data_in_leaf=720 : y = 0.93 : 217.5 secs : infill_ei
#
# Mon Nov 03 05:26:59 AM 2025 AUC 0.926176846724522
#
# [mbo] 77: num_iterations=2048; learning_rate=0.207; feature_fraction=0.998; num_leaves=869; min_data_in_leaf=3284 : y = 0.926 : 215.6 secs : infill_ei
#
# Saved the current state after iteration 78 in the file bayesiana.RDATA.
#
# Mon Nov 03 05:29:57 AM 2025 AUC 0.925473798499793
#
# [mbo] 78: num_iterations=1223; learning_rate=0.01; feature_fraction=0.343; num_leaves=2039; min_data_in_leaf=4881 : y = 0.925 : 177.3 secs : infill_ei
#
# Mon Nov 03 05:35:26 AM 2025 AUC 0.923934958539195
#
# [mbo] 79: num_iterations=2048; learning_rate=0.3; feature_fraction=0.454; num_leaves=11; min_data_in_leaf=4367 : y = 0.924 : 328.1 secs : infill_ei
#
# Mon Nov 03 05:37:10 AM 2025 AUC 0.924512706550314
#
# [mbo] 80: num_iterations=1317; learning_rate=0.0102; feature_fraction=0.999; num_leaves=9; min_data_in_leaf=7973 : y = 0.925 : 104.2 secs : infill_ei
#
# Saved the current state after iteration 81 in the file bayesiana.RDATA.
#
# Mon Nov 03 05:40:39 AM 2025 AUC 0.930553232565439
#
# [mbo] 81: num_iterations=996; learning_rate=0.0102; feature_fraction=0.411; num_leaves=1904; min_data_in_leaf=597 : y = 0.931 : 207.5 secs : infill_ei
#
# Mon Nov 03 05:42:08 AM 2025 AUC 0.926430329975924
#
# [mbo] 82: num_iterations=907; learning_rate=0.153; feature_fraction=0.999; num_leaves=807; min_data_in_leaf=4108 : y = 0.926 : 89.4 secs : infill_ei
#
# Mon Nov 03 05:43:43 AM 2025 AUC 0.926357251067847
#
# [mbo] 83: num_iterations=537; learning_rate=0.178; feature_fraction=0.542; num_leaves=2046; min_data_in_leaf=3007 : y = 0.926 : 94.5 secs : infill_ei
#
# Mon Nov 03 05:45:21 AM 2025 AUC 0.923357583802185
#
# [mbo] 84: num_iterations=963; learning_rate=0.147; feature_fraction=0.103; num_leaves=440; min_data_in_leaf=2776 : y = 0.923 : 97.4 secs : infill_ei
#
# Mon Nov 03 05:46:43 AM 2025 AUC 0.927432259144588
#
# [mbo] 85: num_iterations=616; learning_rate=0.0113; feature_fraction=0.997; num_leaves=2047; min_data_in_leaf=1605 : y = 0.927 : 81.3 secs : infill_ei
#
# Mon Nov 03 05:47:30 AM 2025 AUC 0.927761799977592
#
# [mbo] 86: num_iterations=642; learning_rate=0.168; feature_fraction=0.983; num_leaves=8; min_data_in_leaf=1081 : y = 0.928 : 45.2 secs : infill_ei
#
# Saved the current state after iteration 87 in the file bayesiana.RDATA.
#
# Mon Nov 03 05:49:26 AM 2025 AUC 0.927642670733932
#
# [mbo] 87: num_iterations=656; learning_rate=0.072; feature_fraction=0.514; num_leaves=1952; min_data_in_leaf=3986 : y = 0.928 : 115.4 secs : infill_ei
#
# Mon Nov 03 05:52:08 AM 2025 AUC 0.92499761835153
#
# [mbo] 88: num_iterations=2044; learning_rate=0.114; feature_fraction=1; num_leaves=101; min_data_in_leaf=7996 : y = 0.925 : 161.8 secs : infill_ei
#
# Mon Nov 03 05:54:35 AM 2025 AUC 0.926846521039043
#
# [mbo] 89: num_iterations=1645; learning_rate=0.0134; feature_fraction=0.999; num_leaves=1994; min_data_in_leaf=5850 : y = 0.927 : 146.1 secs : infill_ei
#
# Mon Nov 03 05:57:13 AM 2025 AUC 0.929685058997399
#
# [mbo] 90: num_iterations=961; learning_rate=0.0192; feature_fraction=0.998; num_leaves=1619; min_data_in_leaf=765 : y = 0.93 : 157.4 secs : infill_ei
#
# Mon Nov 03 05:59:06 AM 2025 AUC 0.925511623401144
#
# [mbo] 91: num_iterations=1183; learning_rate=0.3; feature_fraction=0.999; num_leaves=16; min_data_in_leaf=2234 : y = 0.926 : 112.7 secs : infill_ei
#
# Saved the current state after iteration 92 in the file bayesiana.RDATA.
#
# Mon Nov 03 06:01:48 AM 2025 AUC 0.929077054208815
#
# [mbo] 92: num_iterations=1125; learning_rate=0.0555; feature_fraction=0.999; num_leaves=217; min_data_in_leaf=1174 : y = 0.929 : 160.9 secs : infill_ei
#
# Mon Nov 03 06:04:20 AM 2025 AUC 0.923132592069463
#
# [mbo] 93: num_iterations=1892; learning_rate=0.3; feature_fraction=0.999; num_leaves=1921; min_data_in_leaf=7974 : y = 0.923 : 151.0 secs : infill_ei
#
# Mon Nov 03 06:05:43 AM 2025 AUC 0.929099927709247
#
# [mbo] 94: num_iterations=434; learning_rate=0.0105; feature_fraction=0.375; num_leaves=1724; min_data_in_leaf=844 : y = 0.929 : 82.7 secs : infill_ei
#
# Mon Nov 03 06:11:54 AM 2025 AUC 0.923448568571769
#
# [mbo] 95: num_iterations=2041; learning_rate=0.299; feature_fraction=0.495; num_leaves=2046; min_data_in_leaf=2584 : y = 0.923 : 370.3 secs : infill_ei
#
# Saved the current state after iteration 96 in the file bayesiana.RDATA.
#
# Mon Nov 03 06:14:17 AM 2025 AUC 0.930475877364687
#
# [mbo] 96: num_iterations=691; learning_rate=0.0106; feature_fraction=0.461; num_leaves=1910; min_data_in_leaf=871 : y = 0.93 : 142.5 secs : infill_ei
#
# Mon Nov 03 06:15:25 AM 2025 AUC 0.925884729564367
#
# [mbo] 97: num_iterations=554; learning_rate=0.0579; feature_fraction=0.106; num_leaves=1584; min_data_in_leaf=804 : y = 0.926 : 67.1 secs : infill_ei
#
# Mon Nov 03 06:16:08 AM 2025 AUC 0.928923653793463
#
# [mbo] 98: num_iterations=561; learning_rate=0.0897; feature_fraction=0.998; num_leaves=10; min_data_in_leaf=789 : y = 0.929 : 41.7 secs : infill_ei
#
# Mon Nov 03 06:18:04 AM 2025 AUC 0.928658369254372
#
# [mbo] 99: num_iterations=781; learning_rate=0.137; feature_fraction=0.555; num_leaves=9; min_data_in_leaf=1535 : y = 0.929 : 115.8 secs : infill_ei
#
# Mon Nov 03 06:18:44 AM 2025 AUC 0.919939896324829
#
# [mbo] 100: num_iterations=449; learning_rate=0.0101; feature_fraction=1; num_leaves=664; min_data_in_leaf=6070 : y = 0.92 : 39.7 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_iterations"   "learning_rate"    "feature_fraction" "num_leaves"
#  [5] "min_data_in_leaf" "y"                "dob"              "eol"
#  [9] "error.message"    "exec.time"        "ei"               "error.model"
# [13] "train.time"       "prop.type"        "propose.time"     "se"
# [17] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_iterations learning_rate feature_fraction num_leaves min_data_in_leaf
#             <int>         <num>            <num>      <int>            <int>
# 1:           1975    0.01005033        0.3998111        512              611
# [1] 0.9320882

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 523519
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1975
#
# $learning_rate
# [1] 0.01005033
#
# $feature_fraction
# [1] 0.3998111
#
# $num_leaves
# [1] 512
#
# $min_data_in_leaf
# [1] 611

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}
# Out:
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Nov 03 10:46:09 AM 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-05**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-05**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-05**  en caso de ser necesario.
